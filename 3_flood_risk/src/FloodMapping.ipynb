# %% [markdown]
# **Flood Mapping

# %% [markdown]
# ### 📦 Standard Library
# | Module         |
# |----------------|
# | os             |
# | sys            |
# | glob           |
# | time           |
# | shutil         |
# | argparse       |
# | itertools      |
# | statistics     |
# | json           |
# | zipfile        |
# | requests       |
# | pathlib (Path) |
# | logging (config)|
#
# ### 🌍 Third-Party Libraries
# | Module / Submodule                                                                 |
# |-------------------------------------------------------------------------------------|
# | yaml                                                                                |
# | numpy (np)                                                                          |
# | rasterio                                                                            |
# | rasterio.enums (Resampling)                                                         |
# | rasterio.features                                                                   |
# | rasterio.transform (from_origin)                                                    |
# | rasterio.mask (mask)                                                                |
# | rasterio.merge (merge)                                                              |
# | rasterio.warp (reproject)                                                           |
# | geopandas (gpd)                                                                     |
# | shapely.geometry (box, shape, Point, mapping, Polygon, MultiPolygon, LineString)    |
# | shapely.ops (unary_union)                                                           |
# | matplotlib.pyplot (plt)                                                             |
# | fiona                                                                               |
# | pyproj.CRS                                                                          |
# | whitebox                                                                            |
# | whitebox.whitebox_tools (WhiteboxTools)                                             |
# | osmnx (ox)                                                                          |
# | pystac_client (Client)                                                              |
# | fsspec                                                                              |
# | geodatasets                                                                         |
# | folium                                                                              |
# | folium.FeatureGroup, folium.GeoJson, folium.Map, folium.Html, folium.Element        |
# | branca.colormap (cm)                                                                |
# | msfootprint (msf)                                                                   |

# %%
import yaml
import os

# %%
import sys, os
sys.path.append("D:/g20/")  # adjust to your project root

# %%
# Load Config file: 
config_file = "D:/g20/src/config/config.yaml"
with open(config_file, 'r') as f:
    config = yaml.safe_load(f)

# %%
import src.dtmprocessing.hydrocondition as hydro
hydro.main_hydrocondition(config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import src.dtmprocessing.hydrocondition as hydro
#       2 hydro.main_hydrocondition(config)
#
# File D:\g20\src\dtmprocessing\hydrocondition.py:485
#     482 with open(config_file, 'r') as f:
#     483     config = yaml.safe_load(f)
# --> 485 main_hydrocondition(config_file)
#
# File D:\g20\src\dtmprocessing\hydrocondition.py:446, in main_hydrocondition(config)
#     443 def main_hydrocondition(config):
# --> 446     BASE_DIR = config["mainprojectfolder"]
#     447     study_area = config['projectboundary']
#     449     dem_folder = config['dtm_folder']
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# import src.risk.risk_with_hybriddHAND as risk
# stats = risk.rocess_rasters(config)

# %%
from src.exposure import osm_emergfaciltites
osm_emergfaciltites.main_osmdata(config)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from src.exposure import osm_emergfaciltites
#       2 osm_emergfaciltites.main_osmdata(config)
#
# File D:\g20\src\exposure\osm_emergfaciltites.py:4
#       2 import yaml
#       3 import geopandas as gpd
# ----> 4 import osmnx as ox
#       5 from shapely.geometry import Polygon, MultiPolygon
#       6 from shapely.ops import unary_union
#
# ModuleNotFoundError: No module named 'osmnx'
